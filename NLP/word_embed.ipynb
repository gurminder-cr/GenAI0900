# %%
sent= ['the glass of milk',
       'the glass of juice',
       'the cup of tea',
       'he is a good boy',
       'he is a good developer',
       'you are very smart']

# %%
from tensorflow.keras.preprocessing.text import one_hot
# pip install tensorflow # -- tensorflow pypi

# %%
vocab_size=50

# %%
one_hot_sent= [one_hot(i,vocab_size) for i in sent]
one_hot_sent
# Out:
# [[17, 43, 25, 30],
#  [17, 43, 25, 35],
#  [17, 34, 25, 23],
#  [19, 32, 9, 11, 40],
#  [19, 32, 9, 11, 21],
#  [35, 40, 23, 44]]

# %%
# word embedding  -- this layer is responsible for converting wordlayer to vector

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding

# %%
sent_length=7

# %%
embedded_docs= pad_sequences(one_hot_sent,maxlen=sent_length,padding='pre') # padding- post, pre
embedded_docs
# Out:
# array([[ 0,  0,  0, 17, 43, 25, 30],
#        [ 0,  0,  0, 17, 43, 25, 35],
#        [ 0,  0,  0, 17, 34, 25, 23],
#        [ 0,  0, 19, 32,  9, 11, 40],
#        [ 0,  0, 19, 32,  9, 11, 21],
#        [ 0,  0,  0, 35, 40, 23, 44]])

# %%
model=Sequential()
model.add(Embedding(vocab_size,5,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# array([[[-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [ 0.00589544, -0.01979275, -0.00236683,  0.03945403,
#           0.00131543],
#         [ 0.00461202, -0.03525666,  0.01201367, -0.01065512,
#          -0.02559651],
#         [ 0.00598421, -0.03141955,  0.00829641, -0.01666056,
#          -0.01819353],
#         [ 0.03382409,  0.00985558, -0.00701637,  0.00345042,
#           0.02216995]],
#
#        [[-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [ 0.00589544, -0.01979275, -0.00236683,  0.03945403,
#           0.00131543],
#         [ 0.00461202, -0.03525666,  0.01201367, -0.01065512,
#          -0.02559651],
#         [ 0.00598421, -0.03141955,  0.00829641, -0.01666056,
#          -0.01819353],
#         [ 0.02389579, -0.02762203,  0.04983542,  0.03431351,
#          -0.00231744]],
#
#        [[-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [ 0.00589544, -0.01979275, -0.00236683,  0.03945403,
#           0.00131543],
#         [-0.02354398, -0.02594   ,  0.04139959,  0.0447229 ,
#          -0.01334674],
#         [ 0.00598421, -0.03141955,  0.00829641, -0.01666056,
#          -0.01819353],
#         [ 0.04301871,  0.01299058, -0.02303896,  0.00869664,
#          -0.01007022]],
#
#        [[-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [ 0.03355351,  0.02568604, -0.01053885, -0.03623458,
#           0.03318795],
#         [ 0.03545639,  0.01487173,  0.00331794, -0.0463475 ,
#           0.00525795],
#         [-0.00782239, -0.04688429, -0.00284889,  0.0092893 ,
#          -0.03294226],
#         [ 0.02592245, -0.04347626,  0.0214848 , -0.01031734,
#          -0.04070237],
#         [ 0.02698973, -0.00988964, -0.04442064, -0.00818782,
#           0.01688849]],
#
#        [[-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [ 0.03355351,  0.02568604, -0.01053885, -0.03623458,
#           0.03318795],
#         [ 0.03545639,  0.01487173,  0.00331794, -0.0463475 ,
#           0.00525795],
#         [-0.00782239, -0.04688429, -0.00284889,  0.0092893 ,
#          -0.03294226],
#         [ 0.02592245, -0.04347626,  0.0214848 , -0.01031734,
#          -0.04070237],
#         [-0.03498711, -0.00520357,  0.01220714,  0.03938139,
#          -0.00978917]],
#
#        [[-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [-0.00319686,  0.01325205, -0.01476467, -0.00146549,
#           0.00882836],
#         [ 0.02389579, -0.02762203,  0.04983542,  0.03431351,
#          -0.00231744],
#         [ 0.02698973, -0.00988964, -0.04442064, -0.00818782,
#           0.01688849],
#         [ 0.04301871,  0.01299058, -0.02303896,  0.00869664,
#          -0.01007022],
#         [ 0.01761428, -0.00251031, -0.04633523,  0.04491986,
#           0.0109875 ]]], dtype=float32)
