# %%
# Matplotlib - library visualization 
# pip install matplotlib 

import matplotlib.pyplot as plt

# %%
# Bar chart
# Scatter Chart 
# Pie Chart
# Line chart 

# bar chart

fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
sales = [400, 350, 300, 450]

plt.bar(x=fruits, height=sales, width=0.6) # x axis - categories, y-axis - numerical values
plt.show()

# %%
import seaborn as sns 
# sns.barplot(x=fruits , y=sales)
sns.barplot(x=sales , y=fruits)
# Out:
# <Axes: >

# %%
plt.bar(x=fruits, height=sales, width=0.6, color=['red','yellow','green','blue']) # x axis - categories, y-axis - numerical values
plt.show()

# %%
plt.bar(x=fruits, height=sales, width=0.6, color=['red','yellow','green','blue']) # x axis - categories, y-axis - numerical values
plt.xlabel('Fruits')
plt.ylabel('Sales')
plt.title("Sales vs Fruits")
plt.show()

# %%
plt.barh(y=fruits, width=[120,150,190,200], height=0.6, color=['red','yellow','green','blue']) # x axis - categories, y-axis - numerical values
plt.xlabel('Sales')
plt.ylabel('Fruits')
plt.title("Sales vs Fruits")
plt.show()

# %%
# Scatter Plot
# both sides numerical data 
import numpy as np
x = np.array([12, 45, 7, 32, 89, 54, 23, 67, 14, 91])
y = np.array([99, 31, 72, 56, 19, 88, 43, 61, 35, 77])

# %%
plt.scatter(x=x,y=y)
plt.legend()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22724\2306871080.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
x1 = np.array([12, 45, 7, 32, 89, 54, 23, 67, 14, 91])
y1= np.array([99, 31, 72, 56, 19, 88, 43, 61, 35, 77])

x2= np.array([13, 51, 17, 32, 80, 51, 20, 67, 14, 91])
y2 = np.array([99, 31, 21, 60,9, 81, 43, 17, 35, 77])

plt.scatter(x=x1,y=y1, label='Group1', color='red')
plt.scatter(x=x2,y=y2, label='Group2', color='green')
plt.legend()

# %%
x = np.array([12, 45, 7, 32, 89, 54, 23, 67, 14, 91])
y = np.array([99, 31, 72, 56, 19, 88, 43, 61, 35, 77])
l=[10,50,9,16,18,20,22,21,7,19]
# label=['male','female','male','male','female','female','male','female','male','male']
plt.scatter(x=x,y=y,s=l) # size
plt.legend()
plt.grid(True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22724\3876171327.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# pie chart 

country=['India','Pakistan','Bangladesh','Nepal','Spain']
values=[200,180,230,100,120]

plt.pie(x=values, labels=country)
plt.show()

# %%
plt.pie(x=values, labels=country, autopct="%1.1F%%")
plt.title('Countries Data')
plt.grid(True)
plt.show()

# %%
# line chart 
data=[12,13,14,18,20,24,27,28]
y=[20,21,22,23,24,25,26,27]
plt.plot(data, y)
plt.grid(True)
plt.show()
