# %%
import pandas as pd
# df= pd.read_excel('')
df=pd.read_csv('Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin', inplace=True, axis=1)  # axis=1 column, axis=0 row

# %%
df.shape
# Out:
# (891, 11)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Name[:10]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
new= df.Name.str.split(',').str[1].str.split('.').str[0].str.strip()
new
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Name, Length: 891, dtype: object

# %%
new
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Name, Length: 891, dtype: object

# %%
df.insert(6,column='start',value=new)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age start  \
# 0                            Braund, Mr. Owen Harris    male  22.0    Mr
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0   Mrs
# 2                             Heikkinen, Miss. Laina  female  26.0  Miss
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0   Mrs
# 4                           Allen, Mr. William Henry    male  35.0    Mr
#
#    SibSp  Parch            Ticket     Fare Embarked
# 0      1      0         A/5 21171   7.2500        S
# 1      1      0          PC 17599  71.2833        C
# 2      0      0  STON/O2. 3101282   7.9250        S
# 3      1      0            113803  53.1000        S
# 4      0      0            373450   8.0500        S

# %%
mr_df= df[df.loc[:,'start']=='Mr']

# %%
mr_df
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age start  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
mr_age_mean= mr_df.Age.mean()

# %%
mr_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            119
# start            0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
mr_df[mr_df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 5              6         0       3              Moran, Mr. James  male  NaN
# 17            18         1       2  Williams, Mr. Charles Eugene  male  NaN
# 26            27         0       3       Emir, Mr. Farred Chehab  male  NaN
# 29            30         0       3           Todoroff, Mr. Lalio  male  NaN
# 36            37         1       3              Mamee, Mr. Hanna  male  NaN
# ..           ...       ...     ...                           ...   ...  ...
# 839          840         1       1          Marechal, Mr. Pierre  male  NaN
# 846          847         0       3      Sage, Mr. Douglas Bullen  male  NaN
# 859          860         0       3              Razi, Mr. Raihed  male  NaN
# 868          869         0       3   van Melkebeke, Mr. Philemon  male  NaN
# 878          879         0       3            Laleff, Mr. Kristo  male  NaN
#
#     start  SibSp  Parch    Ticket     Fare Embarked
# ...

# %%
mr_index = mr_df[mr_df.Age.isnull()].index

# %%
mr_index
# Out:
# Index([  5,  17,  26,  29,  36,  42,  45,  46,  48,  55,
#        ...
#        825, 826, 828, 832, 837, 839, 846, 859, 868, 878],
#       dtype='int64', length=119)

# %%
df.loc[mr_index,'Age']=mr_age_mean

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            58
# start           0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        2
# dtype: int64

# %%
# df.loc[mr_index,:]

# %%
mrs_df= df[df.loc[:,'start']=='Mrs']

# %%
mrs_df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            17
# start           0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        1
# dtype: int64

# %%
mrs_age_mean= mrs_df.Age.mean()

# %%
mrs_age_mean
# Out:
# 35.898148148148145

# %%
mrs_index = mrs_df[mrs_df.Age.isnull()].index

# %%
mrs_index
# Out:
# Index([ 19,  31, 140, 166, 186, 256, 334, 347, 367, 375, 415, 431, 457, 533,
#        578, 669, 849],
#       dtype='int64')

# %%
df.loc[mrs_index,'Age']= mrs_age_mean

# %%
df.loc[mrs_index,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 19            20         1       3
# 31            32         1       1
# 140          141         0       3
# 166          167         1       1
# 186          187         1       3
# 256          257         1       1
# 334          335         1       1
# 347          348         1       3
# 367          368         1       3
# 375          376         1       1
# 415          416         0       3
# 431          432         1       3
# 457          458         1       1
# 533          534         1       3
# 578          579         0       3
# 669          670         1       1
# 849          850         1       1
#
#                                                   Name     Sex        Age  \
# 19                             Masselmani, Mrs. Fatima  female  35.898148
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  35.898148
# 140                      Boulos, Mrs. Joseph (Sultana)  female  35.898148
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            41
# start           0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        2
# dtype: int64
