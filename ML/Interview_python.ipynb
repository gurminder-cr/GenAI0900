# %%
l=[23,45,110,32,10]
for i in l:
    print(i)
# Out:
# 23
# 45
# 110
# 32
# 10

# %%
iterable= iter(l)

# %%
iterable

# %%
next(iterable)
# Out:
# 45

# %%
next(iterable)
# Out:
# 110

# %%
next(iterable)
# Out:
# 32

# %%
next(iterable)
# Out:
# 10

# %%
next(iterable)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 next(iterable)
#
# StopIteration:

# %%
# # Generator
# def myfunc():
#     # return "hello"
#     return "hi"

# print(myfunc())
# Out:
# hi

# %%
def myfunc():
    yield "hi"
    yield "hello"
    yield "Jatin"

# %%
# print(myfunc())
for i in myfunc():
    print(i)
# Out:
# hi
# hello
# Jatin

# %%
l1=[12,34,56,77]
l2=[44,32,11,100,43]

for i,j in zip(l1,l2):
    print(i,":",j)
# Out:
# 12 : 44
# 34 : 32
# 56 : 11
# 77 : 100
