# %%
import pandas as pd 
from sklearn.datasets import make_classification

# %%
data= make_classification(n_samples=1000,n_features=10,n_classes=2, random_state=10)

# %%
x,y= data

# %%
x[0]
# Out:
# array([-1.00583777, -0.37653943, -0.62017967, -0.15756653, -1.12080531,
#        -0.58909086, -1.57457766,  1.67804613,  1.0801799 ,  0.35358714])

# %%
y[0]
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test, y_train,y_test= train_test_split(x,y)

# %%
len(x_train)
# Out:
# 750

# %%
len(x_test)
# Out:
# 250

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred= model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
confusion_matrix(y_pred, y_test)
# Out:
# array([[128,  30],
#        [ 19, 123]], dtype=int64)

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       158
#            1       0.80      0.87      0.83       142
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.8366666666666667

# %%
x1,y1= make_classification(n_samples=10,n_classes=2,n_features=10)

# %%
y1_pred= model.predict(x1)

# %%
y1
# Out:
# array([1, 0, 0, 1, 1, 1, 0, 1, 0, 0])

# %%
accuracy_score(y1,y1_pred)
# Out:
# 0.5

# %%
x1
# Out:
# array([[ 0.29547216, -0.5322098 ,  0.96356446,  0.16261271,  0.10558146,
#         -0.72299561, -1.08421533, -0.03640735,  0.33660486, -0.49266967],
#        [-0.0056221 , -1.43939145, -2.22671442,  0.29457151, -1.1480916 ,
#         -1.98582886, -1.25122691, -1.55234464, -0.63988149, -0.59991647],
#        [-1.10137293,  1.40890685,  1.48920504, -1.25802257, -0.65673985,
#         -0.04010842,  1.05404482, -0.93914994, -0.99077532, -0.03617864],
#        [ 0.86931985, -0.78319787,  2.22707303,  1.31093553,  0.48031629,
#         -0.79470682, -0.09124745, -0.96563851, -0.62705874, -0.21103841],
#        [-1.03271392,  0.81804699, -1.44745957, -0.05643546, -0.98868232,
#          0.57794722,  0.5821725 ,  0.26841385, -0.01129653, -0.08628013],
#        [-0.86286641, -0.4057251 , -0.2204803 , -0.118872  , -2.33505644,
#         -0.72127801, -0.89889715, -0.19002279,  0.17024209, -0.78908203],
#        [-1.28031866,  0.16926385, -1.31619144, -1.57621714,  2.12799933,
#         -1.72124035, -1.90947518, -0.65165163,  0.19278174,  2.0218837 ],
#        [-0.56771305,  0.16863036, -0.45232202,  1.07932844,  0.63310483,
#         -0.44754286, -0.96766753,  0.22686648,  0.4770119 , -0.57174785],
#        [ 1.9812551 ,  0.07724524,  1.19806253, -0.8210644 ,  1.11802486,
#         -0.09976322,  1.60148567, -1.47784107, -1.54002798,  1.05860694],
#        [-0.04899185,  0.80111517,  3.26857057,  0.39647563,  0.21189831,
#         -1.22262645, -0.57289201, -1.12181967, -0.57285465,  1.1573257 ]])

# %%
x[1]
# Out:
# array([ 0.41117999,  0.76240872, -0.78421   , -0.09647917, -0.40875846,
#        -0.66578006,  0.21094182, -0.85044853, -0.46130068,  1.06223729])

# %%
# Out:
# array([[-1.00583777, -0.37653943, -0.62017967, ...,  1.67804613,
#          1.0801799 ,  0.35358714],
#        [ 0.41117999,  0.76240872, -0.78421   , ..., -0.85044853,
#         -0.46130068,  1.06223729],
#        [-1.52540752,  2.22793382,  0.5477266 , ...,  2.44004248,
#          1.69891857, -0.70530243],
#        ...,
#        [-1.614926  ,  0.74310266,  1.13675653, ...,  2.8471565 ,
#         -0.91145218, -1.22062837],
#        [-0.14262151, -1.43323743, -2.54920034, ...,  0.39777869,
#         -0.71639987,  0.6122551 ],
#        [-0.1251796 ,  0.73011191, -1.87888552, ...,  0.74154153,
#          0.30886522, -1.36966537]])
