# %%
import pandas as pd

# %%
data = pd.read_csv('height-weight.csv')

# %%
data.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
data.loc[:,['Weight']]= scaler.fit_transform(data.loc[:,['Weight']])
data.loc[:,['Height']]= scaler.fit_transform(data.loc[:,['Height']])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_20960\214210053.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.64913128 -0.90540541 -1.47750223 -0.79098604 -0.21888922  0.23878824
#   0.3532076   0.92530443  1.21135284  0.23878824  0.46762697  1.21135284
#   1.78344966  1.49740125  0.63925602  0.23878824 -1.36308287 -0.50493763
#   0.12436887  0.75367538 -1.64913128 -1.01982477 -0.10446985]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,['Weight']]= scaler.fit_transform(data.loc[:,['Weight']])
# C:\Users\hp\AppData\Local\Temp\ipykernel_20960\214210053.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-2.01183323 -1.22578288 -1.85462316 -0.7017493   0.08430105  0.18910777
#   0.24151112  0.87035141  1.23717491  0.60833462  0.92275477  1.23717491
#   0.87035141  1.28957827  0.60833462  0.97515812 -0.96376609  0.0318977
#  -0.43973252  0.45112455 -1.54020302 -0.96376609  0.08430105]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,['Height']]= scaler.fit_transform(data.loc[:,['Height']])

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data.Weight, y=data.Height)
plt.show()

# %%
# Independent Variable
# Dependent Variable 
x=data.Weight
y=data.Height

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=10)

# %%
x_train
# Out:
# 13    1.497401
# 14    0.639256
# 3    -0.790986
# 21   -1.019825
# 6     0.353208
# 18    0.124369
# 10    0.467627
# 19    0.753675
# 22   -0.104470
# 8     1.211353
# 16   -1.363083
# 17   -0.504938
# 0    -1.649131
# 15    0.238788
# 4    -0.218889
# 9     0.238788
# Name: Weight, dtype: float64

# %%
y_train
# Out:
# 13    1.289578
# 14    0.608335
# 3    -0.701749
# 21   -0.963766
# 6     0.241511
# 18   -0.439733
# 10    0.922755
# 19    0.451125
# 22    0.084301
# 8     1.237175
# 16   -0.963766
# 17    0.031898
# 0    -2.011833
# 15    0.975158
# 4     0.084301
# 9     0.608335
# Name: Height, dtype: float64

# %%
x_test
# Out:
# 5     0.238788
# 1    -0.905405
# 7     0.925304
# 2    -1.477502
# 11    1.211353
# 12    1.783450
# 20   -1.649131
# Name: Weight, dtype: float64

# %%
y_test
# Out:
# 5     0.189108
# 1    -1.225783
# 7     0.870351
# 2    -1.854623
# 11    1.237175
# 12    0.870351
# 20   -1.540203
# Name: Height, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
x_train= pd.DataFrame(x_train)
y_train= pd.DataFrame(y_train)
x_test= pd.DataFrame(x_test)
y_test= pd.DataFrame(y_test)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#       Weight
# 5   0.238788
# 1  -0.905405
# 7   0.925304
# 2  -1.477502
# 11  1.211353
# 12  1.783450
# 20 -1.649131

# %%
y_pred= model.predict(x_test)
y_pred
# Out:
# array([[ 0.32537608],
#        [-0.76227426],
#        [ 0.97796628],
#        [-1.30609943],
#        [ 1.24987886],
#        [ 1.79370403],
#        [-1.46924698]])

# %%
y_test
# Out:
#       Height
# 5   0.189108
# 1  -1.225783
# 7   0.870351
# 2  -1.854623
# 11  1.237175
# 12  0.870351
# 20 -1.540203

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8609415967399181

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.2005206781767463
